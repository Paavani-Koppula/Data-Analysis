# %%
import numpy as np
#generate a large volume of random data(e.g., 1 million data points)
volume_data=np.random.rand(1000000)
print("Volume of data:",len(volume_data))
# Out:
# Volume of data: 1000000

# %%
import time
#simuulate streaming data every second for 10 seconds
for i in range(10):
  velocity_data=np.random.rand() #generate random data
  print("Velocity data pount:",velocity_data)
  time.sleep(1) #wait for 1 second to simulates real-time data stream
# Out:
# Velocity data pount: 0.2882276418320534
# Velocity data pount: 0.19295806231150403
# Velocity data pount: 0.2672772701155195
# Velocity data pount: 0.9569230215781372
# Velocity data pount: 0.7184562000903749
# Velocity data pount: 0.3350328640196574
# Velocity data pount: 0.4034521325218846
# Velocity data pount: 0.18700624699608193
# Velocity data pount: 0.4950404877276279
# Velocity data pount: 0.46091632494346935

# %%
#structured data
structured_data={'id':1,'name':'john','age':30}
print(structured_data)
#semistructured data
semi_structured_data={'person':{'name':'Alice','age':25,'city':'Newyork'}}
#unstructured data
unstructured_data='This is a sample text document.It can contain any information in form of'
# Out:
# {'id': 1, 'name': 'john', 'age': 30}

# %%
import random
#generate somerandom data with noise
veracity_data=[random.choice([1,2,3,None])for _ in range(20)]
print("veracity data:",veracity_data)
# Out:
# veracity data: [None, 1, 2, 3, 2, 1, 2, 1, None, 3, 1, 2, 2, 3, 1, 1, 1, None, 1, 3]

# %%
# !pip install pyspark
