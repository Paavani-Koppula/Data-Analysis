# %%
#load libraries
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz,plot_tree
from IPython.display import Image

# %%
df=pd.read_csv("/content/demoDT.csv")
print(df)

# %%
feature_cols=['Literacy',' Cleanliness',' Crime_Rate']
feature=df[feature_cols] #features
Target=df.Good #target variable

# %%
#create decision tree classifer object
DT=DecisionTreeClassifier()
#train decision tree classifier
DT=DT.fit(feature,Target)

# %%
#predict the response for test dataset
l=int(input("Enter Literacy:"))
cl=int(input("Enter Cleanliness:"))
cr=int(input("Enter Crimerate:"))
pred=DT.predict([[l,cl,cr]])
if pred==1:
  print("good state")
else:
  print("bad state")
# Out:
# Enter Literacy:92
# Enter Cleanliness:90
# Enter Crimerate:54
# bad state
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plot_tree(DT) #plot_tree(trained model name)
# Out:
# [Text(0.5, 0.9, 'x[1] <= 75.5\ngini = 0.488\nsamples = 26\nvalue = [15, 11]'),
#  Text(0.2, 0.7, 'x[2] <= 58.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3, 0.5, 'x[2] <= 62.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.2, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4, 0.3, 'x[2] <= 65.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.7, 'x[2] <= 46.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.7, 0.5, 'x[0] <= 87.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.6, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8, 0.3, 'x[1] <= 89.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]')]

# %%
#load libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
#from sklearn.tree import export_graphviz,plot_tree
#from IPython.display import Image

# %%
df=pd.read_csv("/content/demoDT.csv")
print(df)
# Out:
#    State  Literacy   Cleanliness   Crime_Rate  Good
# 0      A        92            90           54     0
# 1      B        56            67           50     1
# 2      C        78            80           62     0
# 3      D        85            75           48     1
# 4      E        60            82           55     0
# 5      F        72            78           60     0
# 6      G        88            85           45     0
# 7      H        64            70           58     1
# 8      I        90            88           42     0
# 9      J        68            72           65     1
# 10     K        75            79           57     0
# 11     L        82            86           49     0
# 12     M        58            65           63     1
# 13     N        77            76           52     0
# 14     O        94            91           40     1
# 15     P        63            74           61     0
# 16     Q        79            83           47     0
# 17     R        71            68           59     0
# 18     S        86            89           43     1
# 19     T        66            71           64     1
# 20     U        81            81           51     0
# 21     V        70            77           56     0
# 22     W        87            84           46     1
# 23     X        62            69           66     0
# 24     Y        76            73           53     1
# 25     Z        83            87           44     1

# %%
feature_cols=['Literacy',' Cleanliness',' Crime_Rate']
feature=df[feature_cols] #features
Target=df.Good #target variable

# %%
RF=RandomForestClassifier(n_estimators=10)
RF.fit(feature,Target)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
#predict the response for test dataset
l=int(input("Enter Literacy:"))
cl=int(input("Enter Cleanliness:"))
cr=int(input("Enter Crimerate:"))
pred=DT.predict([[l,cl,cr]])
if pred==1:
  print("good state")
else:
  print("bad state")
# Out:
# Enter Literacy:92
# Enter Cleanliness:90
# Enter Crimerate:54
# bad state
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#saving all decision tree
import os
output_dir="tree_visualizations"
os.makedirs(output_dir,exist_ok=True)

# %%
RF.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1645180595),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1946968617),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1512534616),
#  DecisionTreeClassifier(max_features='sqrt', random_state=344872402),
#  DecisionTreeClassifier(max_features='sqrt', random_state=569717764),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1322263980),
#  DecisionTreeClassifier(max_features='sqrt', random_state=717290493),
#  DecisionTreeClassifier(max_features='sqrt', random_state=293913283),
#  DecisionTreeClassifier(max_features='sqrt', random_state=109501343),
#  DecisionTreeClassifier(max_features='sqrt', random_state=342509721)]
